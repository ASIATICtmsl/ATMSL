# %%
# Step 1: Import necessary libraries
import pandas as pd

# Step 2: Load the CSV file
# Replace 'your_file.csv' with the path to your actual CSV file
file_path = '/content/drive/MyDrive/Copy of BFI-2.csv'
data = pd.read_csv(file_path)

# Step 3: Function to extract traits for a specific name and categorize them
def extract_traits(name):
    # Filter the dataframe for the given name
    person_data = data[data['Name:'] == name]

    if person_data.empty:
        return f"No data found for {name}."

    # Assuming the traits are all columns except the 'Name' column
    traits = person_data.drop(columns=['Name:']).T
    traits.columns = ['Value']

    # Step 4: Categorize traits based on their values
    categories = {
        'Very High': [],
        'High': [],
        'Medium': [],
        'Low': [],
        'Very Low': []
    }

    for trait, value in traits['Value'].items():
        if value == 'Very High':
            categories['Very High'].append(trait)
        elif value == 'High':
            categories['High'].append(trait)
        elif value == 'Medium':
            categories['Medium'].append(trait)
        elif value == 'Low':
            categories['Low'].append(trait)
        elif value == 'Very Low':
            categories['Very Low'].append(trait)

    # Step 5: Display results in a structured manner
    print(f"Traits for {name}:")
    for category, traits_list in categories.items():
        print(f"\n{category} ({len(traits_list)} traits):")
        for trait in traits_list:
            print(f" - {trait}")

# Example usage
name_to_search = 'Masum'
extract_traits(name_to_search)
# Out:
# Traits for Masum:
#
# Very High (0 traits):
#
# High (12 traits):
#  - Agreeableness
#  - Conscientiousness
#  - Open-Mindedness
#  - Compassion
#  - Respectfulness
#  - Trust
#  - Organization
#  - Productiveness
#  - Responsibility
#  - Intellectual Curiosity
#  - Aesthetic Sensitivity
#  - Creative Imagination
#
# Medium (4 traits):
#  - Extraversion
#  - Assertiveness
#  - Energy Level
#  - Anxiety
#
# Low (4 traits):
#  - Negative Emotionality
#  - Sociability
#  - Depression
#  - Emotional Volatility
#
# Very Low (0 traits):

# %%
# Step 1: Import necessary libraries
import pandas as pd

# Step 2: Load the CSV file
# Replace 'your_file.csv' with the path to your actual CSV file
file_path = '/content/drive/MyDrive/Copy of BFI-2.csv'
data = pd.read_csv(file_path)

# Step 3: Define the fixed set of 20 columns
fixed_columns = [
    'Agreeableness', 'Conscientiousness', 'Open-Mindedness', 'Compassion',
    'Respectfulness', 'Trust', 'Organization', 'Productiveness',
    'Responsibility', 'Intellectual Curiosity', 'Aesthetic Sensitivity',
    'Creative Imagination', 'Extraversion', 'Assertiveness', 'Energy Level',
    'Anxiety', 'Negative Emotionality', 'Sociability', 'Depression',
    'Emotional Volatility'
]

# Step 4: Function to extract traits for a specific name and categorize them
def extract_traits(name):
    # Filter the dataframe for the given name
    person_data = data[data['Name:'] == name]

    if person_data.empty:
        return f"No data found for {name}."

    # Ensure only the fixed set of columns are considered
    person_data = person_data[fixed_columns]

    # Transpose the dataframe to switch rows and columns for easier processing
    traits = person_data.T
    traits.columns = ['Value']

    # Step 5: Categorize traits based on their values
    categories = {
        'Very High': [],
        'High': [],
        'Medium': [],
        'Low': [],
        'Very Low': []
    }

    for trait, value in traits['Value'].items():
        if value == 'Very High':
            categories['Very High'].append(trait)
        elif value == 'High':
            categories['High'].append(trait)
        elif value == 'Medium':
            categories['Medium'].append(trait)
        elif value == 'Low':
            categories['Low'].append(trait)
        elif value == 'Very Low':
            categories['Very Low'].append(trait)

    # Step 6: Display results in a structured manner
    print(f"Traits for {name}:")
    for category, traits_list in categories.items():
        print(f"\n{category} ({len(traits_list)} traits):")
        for trait in traits_list:
            print(f" - {trait}")

# Example usage
name_to_search = 'Masum'
extract_traits(name_to_search)
# Out:
# Traits for Masum:
#
# Very High (0 traits):
#
# High (12 traits):
#  - Agreeableness
#  - Conscientiousness
#  - Open-Mindedness
#  - Compassion
#  - Respectfulness
#  - Trust
#  - Organization
#  - Productiveness
#  - Responsibility
#  - Intellectual Curiosity
#  - Aesthetic Sensitivity
#  - Creative Imagination
#
# Medium (4 traits):
#  - Extraversion
#  - Assertiveness
#  - Energy Level
#  - Anxiety
#
# Low (4 traits):
#  - Negative Emotionality
#  - Sociability
#  - Depression
#  - Emotional Volatility
#
# Very Low (0 traits):

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from IPython.display import display, HTML

# Load the CSV file
file_path = '/content/drive/MyDrive/Copy of BFI-2.csv'  # Replace with the actual file path
data = pd.read_csv(file_path)

# Define the fixed set of 20 columns
fixed_columns = [
    'Agreeableness', 'Conscientiousness', 'Open-Mindedness', 'Compassion',
    'Respectfulness', 'Trust', 'Organization', 'Productiveness',
    'Responsibility', 'Intellectual Curiosity', 'Aesthetic Sensitivity',
    'Creative Imagination', 'Extraversion', 'Assertiveness', 'Energy Level',
    'Anxiety', 'Negative Emotionality', 'Sociability', 'Depression',
    'Emotional Volatility'
]

# Define the descriptions for each level of each trait
descriptions = {
    "Openness": {
        "Very Low": "Prefers routine, traditional.",
        "Low": "Somewhat conventional, slightly resistant to change.",
        "Medium": "Balanced between openness and conventionality.",
        "High": "Creative and open to new experiences.",
        "Very High": "Very creative, imaginative, open to new experiences."
    },
    "Conscientiousness": {
        "Very Low": "Disorganized, spontaneous.",
        "Low": "Somewhat unreliable, prefers flexibility.",
        "Medium": "Moderately organized and dependable.",
        "High": "Organized and reliable.",
        "Very High": "Highly organized, disciplined."
    },
    "Extraversion": {
        "Very Low": "Very reserved, prefers solitude.",
        "Low": "Somewhat reserved, enjoys some solitary activities.",
        "Medium": "Balanced between sociability and reserved behavior.",
        "High": "Outgoing and sociable.",
        "Very High": "Highly outgoing, energetic, and sociable."
    },
    "Agreeableness": {
        "Very Low": "Competitive, less cooperative.",
        "Low": "Somewhat self-centered, less empathetic.",
        "Medium": "Average in cooperation and compassion.",
        "High": "Cooperative and compassionate.",
        "Very High": "Highly cooperative, kind, and compassionate."
    },
    "Neuroticism": {
        "Very Low": "Very emotionally stable and calm.",
        "Low": "Generally calm, less prone to stress.",
        "Medium": "Average in emotional stability.",
        "High": "Somewhat prone to stress, more sensitive.",
        "Very High": "Prone to stress, emotional instability."
    }
}

# Function to generate the personality profile
def generate_profile(O, C, E, A, N):
    O_desc = descriptions["Openness"][O]
    C_desc = descriptions["Conscientiousness"][C]
    E_desc = descriptions["Extraversion"][E]
    A_desc = descriptions["Agreeableness"][A]
    N_desc = descriptions["Neuroticism"][N]
    profile = (
        f"<h2>Personality Profile</h2>"
        f"<p><strong>Openness:</strong> {O_desc}</p>"
        f"<p><strong>Conscientiousness:</strong> {C_desc}</p>"
        f"<p><strong>Extraversion:</strong> {E_desc}</p>"
        f"<p><strong>Agreeableness:</strong> {A_desc}</p>"
        f"<p><strong>Neuroticism:</strong> {N_desc}</p>"
        f"<h3>Summary</h3>"
        f"<p>This individual is likely to be {O_desc.split(',')[0].lower()} and {C_desc.split(',')[0].lower()}. "
        f"They may be {E_desc.split(',')[0].lower()} and {A_desc.split(',')[0].lower()}. They handle stress {N_desc.split(',')[0].lower()}.</p>"
    )
    return profile

# Function to extract traits for a specific name and categorize them
def extract_traits(name):
    # Filter the dataframe for the given name
    person_data = data[data['Name:'] == name]

    if person_data.empty:
        return f"No data found for {name}."

    # Ensure only the fixed set of columns are considered
    person_data = person_data[fixed_columns]

    # Transpose the dataframe to switch rows and columns for easier processing
    traits = person_data.T
    traits.columns = ['Value']

    # Map traits to the OCEAN model
    O = traits.loc[['Open-Mindedness', 'Intellectual Curiosity', 'Aesthetic Sensitivity', 'Creative Imagination']].iloc[:, 0].mode()[0]
    C = traits.loc[['Conscientiousness', 'Organization', 'Productiveness', 'Responsibility']].iloc[:, 0].mode()[0]
    E = traits.loc[['Extraversion', 'Assertiveness', 'Energy Level', 'Sociability']].iloc[:, 0].mode()[0]
    A = traits.loc[['Agreeableness', 'Compassion', 'Respectfulness', 'Trust']].iloc[:, 0].mode()[0]
    N = traits.loc[['Anxiety', 'Negative Emotionality', 'Depression', 'Emotional Volatility']].iloc[:, 0].mode()[0]

    # Generate and display the personality profile
    profile = generate_profile(O, C, E, A, N)
    display(HTML(profile))

# Example usage
name_to_search = 'Masum'
extract_traits(name_to_search)
# Out:
# <h2>Personality Profile</h2><p><strong>Openness:</strong> Creative and open to new experiences.</p><p><strong>Conscientiousness:</strong> Organized and reliable.</p><p><strong>Extraversion:</strong> Balanced between sociability and reserved behavior.</p><p><strong>Agreeableness:</strong> Cooperative and compassionate.</p><p><strong>Neuroticism:</strong> Generally calm, less prone to stress.</p><h3>Summary</h3><p>This individual is likely to be creative and open to new experiences. and organized and reliable.. They may be balanced between sociability and reserved behavior. and cooperative and compassionate.. They handle stress generally calm.</p>

# %%
import pandas as pd
from IPython.display import display, HTML

# Load the CSV file
file_path = '/content/drive/MyDrive/Copy of BFI-2.csv'  # Replace with the actual file path
data = pd.read_csv(file_path)

# Define the fixed set of 20 columns
fixed_columns = [
    'Agreeableness', 'Conscientiousness', 'Open-Mindedness', 'Compassion',
    'Respectfulness', 'Trust', 'Organization', 'Productiveness',
    'Responsibility', 'Intellectual Curiosity', 'Aesthetic Sensitivity',
    'Creative Imagination', 'Extraversion', 'Assertiveness', 'Energy Level',
    'Anxiety', 'Negative Emotionality', 'Sociability', 'Depression',
    'Emotional Volatility'
]

# Define the descriptions for each level of each trait
descriptions = {
    "Openness": {
        "Very Low": "Prefers routine, traditional.",
        "Low": "Somewhat conventional, slightly resistant to change.",
        "Medium": "Balanced between openness and conventionality.",
        "High": "Creative and open to new experiences.",
        "Very High": "Very creative, imaginative, open to new experiences."
    },
    "Conscientiousness": {
        "Very Low": "Disorganized, spontaneous.",
        "Low": "Somewhat unreliable, prefers flexibility.",
        "Medium": "Moderately organized and dependable.",
        "High": "Organized and reliable.",
        "Very High": "Highly organized, disciplined."
    },
    "Extraversion": {
        "Very Low": "Very reserved, prefers solitude.",
        "Low": "Somewhat reserved, enjoys some solitary activities.",
        "Medium": "Balanced between sociability and reserved behavior.",
        "High": "Outgoing and sociable.",
        "Very High": "Highly outgoing, energetic, and sociable."
    },
    "Agreeableness": {
        "Very Low": "Competitive, less cooperative.",
        "Low": "Somewhat self-centered, less empathetic.",
        "Medium": "Average in cooperation and compassion.",
        "High": "Cooperative and compassionate.",
        "Very High": "Highly cooperative, kind, and compassionate."
    },
    "Neuroticism": {
        "Very Low": "Very emotionally stable and calm.",
        "Low": "Generally calm, less prone to stress.",
        "Medium": "Average in emotional stability.",
        "High": "Somewhat prone to stress, more sensitive.",
        "Very High": "Prone to stress, emotional instability."
    }
}

# Function to generate the personality profile
def generate_profile(O, C, E, A, N):
    O_desc = descriptions["Openness"][O]
    C_desc = descriptions["Conscientiousness"][C]
    E_desc = descriptions["Extraversion"][E]
    A_desc = descriptions["Agreeableness"][A]
    N_desc = descriptions["Neuroticism"][N]
    profile = (
        f"<h2>Personality Profile</h2>"
        f"<p><strong>Openness:</strong> {O_desc}</p>"
        f"<p><strong>Conscientiousness:</strong> {C_desc}</p>"
        f"<p><strong>Extraversion:</strong> {E_desc}</p>"
        f"<p><strong>Agreeableness:</strong> {A_desc}</p>"
        f"<p><strong>Neuroticism:</strong> {N_desc}</p>"
        f"<h3>Summary</h3>"
        f"<p>This individual is likely to be {O_desc.split(',')[0].lower()} and {C_desc.split(',')[0].lower()}. "
        f"They may be {E_desc.split(',')[0].lower()} and {A_desc.split(',')[0].lower()}. They handle stress {N_desc.split(',')[0].lower()}.</p>"
    )
    return profile

# Function to extract traits for a specific name and categorize them
def extract_traits(name):
    # Filter the dataframe for the given name
    person_data = data[data['Name:'] == name]

    if person_data.empty:
        return f"No data found for {name}."

    # Ensure only the fixed set of columns are considered
    person_data = person_data[fixed_columns]

    # Transpose the dataframe to switch rows and columns for easier processing
    traits = person_data.T
    traits.columns = ['Value']

    # Step 4: Categorize traits based on their values
    categories = {
        'Very High': [],
        'High': [],
        'Medium': [],
        'Low': [],
        'Very Low': []
    }

    for trait, value in traits['Value'].items():
        if value == 'Very High':
            categories['Very High'].append(trait)
        elif value == 'High':
            categories['High'].append(trait)
        elif value == 'Medium':
            categories['Medium'].append(trait)
        elif value == 'Low':
            categories['Low'].append(trait)
        elif value == 'Very Low':
            categories['Very Low'].append(trait)

    # Display categorized traits
    print(f"Traits for {name}:")
    for category, traits_list in categories.items():
        print(f"\n{category} ({len(traits_list)} traits):")
        for trait in traits_list:
            print(f" - {trait}")

    # Map traits to the OCEAN model
    O = traits.loc[['Open-Mindedness', 'Intellectual Curiosity', 'Aesthetic Sensitivity', 'Creative Imagination']].iloc[:, 0].mode()[0]
    C = traits.loc[['Conscientiousness', 'Organization', 'Productiveness', 'Responsibility']].iloc[:, 0].mode()[0]
    E = traits.loc[['Extraversion', 'Assertiveness', 'Energy Level', 'Sociability']].iloc[:, 0].mode()[0]
    A = traits.loc[['Agreeableness', 'Compassion', 'Respectfulness', 'Trust']].iloc[:, 0].mode()[0]
    N = traits.loc[['Anxiety', 'Negative Emotionality', 'Depression', 'Emotional Volatility']].iloc[:, 0].mode()[0]

    # Generate and display the personality profile
    profile = generate_profile(O, C, E, A, N)
    display(HTML(profile))

# Example usage
name_to_search = 'Masum'
extract_traits(name_to_search)
# Out:
# Traits for Masum:
#
# Very High (0 traits):
#
# High (12 traits):
#  - Agreeableness
#  - Conscientiousness
#  - Open-Mindedness
#  - Compassion
#  - Respectfulness
#  - Trust
#  - Organization
#  - Productiveness
#  - Responsibility
#  - Intellectual Curiosity
#  - Aesthetic Sensitivity
#  - Creative Imagination
#
# Medium (4 traits):
#  - Extraversion
#  - Assertiveness
#  - Energy Level
#  - Anxiety
#
# Low (4 traits):
#  - Negative Emotionality
#  - Sociability
#  - Depression
#  - Emotional Volatility
#
# Very Low (0 traits):
# <h2>Personality Profile</h2><p><strong>Openness:</strong> Creative and open to new experiences.</p><p><strong>Conscientiousness:</strong> Organized and reliable.</p><p><strong>Extraversion:</strong> Balanced between sociability and reserved behavior.</p><p><strong>Agreeableness:</strong> Cooperative and compassionate.</p><p><strong>Neuroticism:</strong> Generally calm, less prone to stress.</p><h3>Summary</h3><p>This individual is likely to be creative and open to new experiences. and organized and reliable.. They may be balanced between sociability and reserved behavior. and cooperative and compassionate.. They handle stress generally calm.</p>

# %%
import pandas as pd
from IPython.display import display, HTML

# Load the CSV file
file_path = '/content/drive/MyDrive/Copy of BFI-2.csv'  # Replace with the actual file path
data = pd.read_csv(file_path)

# Define the fixed set of 20 columns
fixed_columns = [
    'Agreeableness', 'Conscientiousness', 'Open-Mindedness', 'Compassion',
    'Respectfulness', 'Trust', 'Organization', 'Productiveness',
    'Responsibility', 'Intellectual Curiosity', 'Aesthetic Sensitivity',
    'Creative Imagination', 'Extraversion', 'Assertiveness', 'Energy Level',
    'Anxiety', 'Negative Emotionality', 'Sociability', 'Depression',
    'Emotional Volatility'
]

# Define the descriptions for each level of each trait
descriptions = {
    "Openness": {
        "Very Low": "Prefers routine, traditional.",
        "Low": "Somewhat conventional, slightly resistant to change.",
        "Medium": "Balanced between openness and conventionality.",
        "High": "Creative and open to new experiences.",
        "Very High": "Very creative, imaginative, open to new experiences."
    },
    "Conscientiousness": {
        "Very Low": "Disorganized, spontaneous.",
        "Low": "Somewhat unreliable, prefers flexibility.",
        "Medium": "Moderately organized and dependable.",
        "High": "Organized and reliable.",
        "Very High": "Highly organized, disciplined."
    },
    "Extraversion": {
        "Very Low": "Very reserved, prefers solitude.",
        "Low": "Somewhat reserved, enjoys some solitary activities.",
        "Medium": "Balanced between sociability and reserved behavior.",
        "High": "Outgoing and sociable.",
        "Very High": "Highly outgoing, energetic, and sociable."
    },
    "Agreeableness": {
        "Very Low": "Competitive, less cooperative.",
        "Low": "Somewhat self-centered, less empathetic.",
        "Medium": "Average in cooperation and compassion.",
        "High": "Cooperative and compassionate.",
        "Very High": "Highly cooperative, kind, and compassionate."
    },
    "Neuroticism": {
        "Very Low": "Very emotionally stable and calm.",
        "Low": "Generally calm, less prone to stress.",
        "Medium": "Average in emotional stability.",
        "High": "Somewhat prone to stress, more sensitive.",
        "Very High": "Prone to stress, emotional instability."
    }
}

# Function to generate the personality profile
def generate_profile(O, C, E, A, N):
    O_desc = descriptions["Openness"][O]
    C_desc = descriptions["Conscientiousness"][C]
    E_desc = descriptions["Extraversion"][E]
    A_desc = descriptions["Agreeableness"][A]
    N_desc = descriptions["Neuroticism"][N]
    profile = (
        f"<h2>Personality Profile</h2>"
        f"<p><strong>Openness:</strong> {O_desc}</p>"
        f"<p><strong>Conscientiousness:</strong> {C_desc}</p>"
        f"<p><strong>Extraversion:</strong> {E_desc}</p>"
        f"<p><strong>Agreeableness:</strong> {A_desc}</p>"
        f"<p><strong>Neuroticism:</strong> {N_desc}</p>"
        f"<h3>Summary</h3>"
        f"<p>This individual is likely to be {O_desc.split(',')[0].lower()} and {C_desc.split(',')[0].lower()}. "
        f"They may be {E_desc.split(',')[0].lower()} and {A_desc.split(',')[0].lower()}. They handle stress {N_desc.split(',')[0].lower()}.</p>"
    )
    return profile

# Function to extract traits for a specific name and categorize them
def extract_traits(name):
    # Filter the dataframe for the given name
    person_data = data[data['Name:'] == name]

    if person_data.empty:
        return f"No data found for {name}."

    # Ensure only the fixed set of columns are considered
    person_data = person_data[fixed_columns]

    # Transpose the dataframe to switch rows and columns for easier processing
    traits = person_data.T
    traits.columns = ['Value']

    # Categorize traits based on their values
    categories = {
        'Very High': [],
        'High': [],
        'Medium': [],
        'Low': [],
        'Very Low': []
    }

    for trait, value in traits['Value'].items():
        if value == 'Very High':
            categories['Very High'].append(trait)
        elif value == 'High':
            categories['High'].append(trait)
        elif value == 'Medium':
            categories['Medium'].append(trait)
        elif value == 'Low':
            categories['Low'].append(trait)
        elif value == 'Very Low':
            categories['Very Low'].append(trait)

    # Create an HTML table for categorized traits
    table_html = "<h2>Traits for {}</h2>".format(name)
    for category, traits_list in categories.items():
        table_html += "<h3>{} ({})</h3><ul>".format(category, len(traits_list))
        for trait in traits_list:
            table_html += "<li>{}</li>".format(trait)
        table_html += "</ul>"

    # Map traits to the OCEAN model
    O = traits.loc[['Open-Mindedness', 'Intellectual Curiosity', 'Aesthetic Sensitivity', 'Creative Imagination']].iloc[:, 0].mode()[0]
    C = traits.loc[['Conscientiousness', 'Organization', 'Productiveness', 'Responsibility']].iloc[:, 0].mode()[0]
    E = traits.loc[['Extraversion', 'Assertiveness', 'Energy Level', 'Sociability']].iloc[:, 0].mode()[0]
    A = traits.loc[['Agreeableness', 'Compassion', 'Respectfulness', 'Trust']].iloc[:, 0].mode()[0]
    N = traits.loc[['Anxiety', 'Negative Emotionality', 'Depression', 'Emotional Volatility']].iloc[:, 0].mode()[0]

    # Generate and display the personality profile
    profile = generate_profile(O, C, E, A, N)

    # Display the table and profile using HTML
    display(HTML(table_html))
    display(HTML(profile))

# Example usage
name_to_search = 'Masum'
extract_traits(name_to_search)
# Out:
# <h2>Traits for Masum</h2><h3>Very High (0)</h3><ul></ul><h3>High (12)</h3><ul><li>Agreeableness</li><li>Conscientiousness</li><li>Open-Mindedness</li><li>Compassion</li><li>Respectfulness</li><li>Trust</li><li>Organization</li><li>Productiveness</li><li>Responsibility</li><li>Intellectual Curiosity</li><li>Aesthetic Sensitivity</li><li>Creative Imagination</li></ul><h3>Medium (4)</h3><ul><li>Extraversion</li><li>Assertiveness</li><li>Energy Level</li><li>Anxiety</li></ul><h3>Low (4)</h3><ul><li>Negative Emotionality</li><li>Sociability</li><li>Depression</li><li>Emotional Volatility</li></ul><h3>Very Low (0)</h3><ul></ul>
# <h2>Personality Profile</h2><p><strong>Openness:</strong> Creative and open to new experiences.</p><p><strong>Conscientiousness:</strong> Organized and reliable.</p><p><strong>Extraversion:</strong> Balanced between sociability and reserved behavior.</p><p><strong>Agreeableness:</strong> Cooperative and compassionate.</p><p><strong>Neuroticism:</strong> Generally calm, less prone to stress.</p><h3>Summary</h3><p>This individual is likely to be creative and open to new experiences. and organized and reliable.. They may be balanced between sociability and reserved behavior. and cooperative and compassionate.. They handle stress generally calm.</p>

# %%
import pandas as pd
from IPython.display import display, HTML

# Load the CSV file
file_path = '/content/drive/MyDrive/Copy of BFI-2.csv'
data = pd.read_csv(file_path)

# Define the fixed set of 20 columns
fixed_columns = [
    'Agreeableness', 'Conscientiousness', 'Open-Mindedness', 'Compassion',
    'Respectfulness', 'Trust', 'Organization', 'Productiveness',
    'Responsibility', 'Intellectual Curiosity', 'Aesthetic Sensitivity',
    'Creative Imagination', 'Extraversion', 'Assertiveness', 'Energy Level',
    'Anxiety', 'Negative Emotionality', 'Sociability', 'Depression',
    'Emotional Volatility'
]

# Define the descriptions for each level of each trait
descriptions = {
    "Openness": {
        "Very Low": "prefers routine and traditional",
        "Low": "somewhat conventional and slightly resistant to change",
        "Medium": "balanced between openness and conventionality",
        "High": "creative and open to new experiences",
        "Very High": "very creative and also imaginative and open to new experiences"
    },
    "Conscientiousness": {
        "Very Low": "disorganized and spontaneous",
        "Low": "somewhat unreliable and prefers flexibility",
        "Medium": "moderately organized and dependable",
        "High": "organized and reliable",
        "Very High": "highly organized and disciplined"
    },
    "Extraversion": {
        "Very Low": "very reserved and prefers solitude",
        "Low": "somewhat reserved and enjoys some solitary activities",
        "Medium": "balanced between sociability and reserved behavior",
        "High": "outgoing and sociable",
        "Very High": "highly outgoing also energetic and sociable"
    },
    "Agreeableness": {
        "Very Low": "competitive and less cooperative",
        "Low": "somewhat self-centered and less empathetic",
        "Medium": "average in cooperation and compassion",
        "High": "cooperative and compassionate",
        "Very High": "highly cooperative also kind and compassionate"
    },
    "Neuroticism": {
        "Very Low": "very emotionally stable and calm",
        "Low": "generally calm and less prone to stress",
        "Medium": "average in emotional stability",
        "High": "somewhat prone to stress, more sensitive",
        "Very High": "prone to stress and emotional instability"
    }
}

# Function to generate the personality profile
def generate_profile(O, C, E, A, N):
    O_desc = descriptions["Openness"][O]
    C_desc = descriptions["Conscientiousness"][C]
    E_desc = descriptions["Extraversion"][E]
    A_desc = descriptions["Agreeableness"][A]
    N_desc = descriptions["Neuroticism"][N]

    profile = (
        f"<h2>Personality Profile</h2>"
        f"<p><strong>Openness:</strong> {O_desc.capitalize()}</p>"
        f"<p><strong>Conscientiousness:</strong> {C_desc.capitalize()}</p>"
        f"<p><strong>Extraversion:</strong> {E_desc.capitalize()}</p>"
        f"<p><strong>Agreeableness:</strong> {A_desc.capitalize()}</p>"
        f"<p><strong>Neuroticism:</strong> {N_desc.capitalize()}</p>"
    )

    summary = (
        f"<h3>Summary</h3>"
        f"<p>This individual is likely to be {O_desc.split(',')[0]} also {C_desc.split(',')[0]}. "
        f"They may be {E_desc.split(',')[0]} and {A_desc.split(',')[0]}. They handle stress {N_desc.split(',')[0]}.</p>"
    )

    return profile, summary

# Function to extract traits for a specific name and categorize them
def extract_traits(name):
    # Filter the dataframe for the given name
    person_data = data[data['Name:'] == name]

    if person_data.empty:
        return f"No data found for {name}."

    # Ensure only the fixed set of columns are considered
    person_data = person_data[fixed_columns]

    # Transpose the dataframe to switch rows and columns for easier processing
    traits = person_data.T
    traits.columns = ['Value']

    # Categorize traits based on their values
    categories = {
        'Very High': [],
        'High': [],
        'Medium': [],
        'Low': [],
        'Very Low': []
    }

    for trait, value in traits['Value'].items():
        if value == 'Very High':
            categories['Very High'].append(trait)
        elif value == 'High':
            categories['High'].append(trait)
        elif value == 'Medium':
            categories['Medium'].append(trait)
        elif value == 'Low':
            categories['Low'].append(trait)
        elif value == 'Very Low':
            categories['Very Low'].append(trait)

    # Create an HTML table for categorized traits
    table_html = "<h2>Traits for {}</h2>".format(name)
    for category, traits_list in categories.items():
        table_html += "<h3>{} ({})</h3><ul>".format(category, len(traits_list))
        for trait in traits_list:
            table_html += "<li>{}</li>".format(trait)
        table_html += "</ul>"

    # Map traits to the OCEAN model
    O = traits.loc[['Open-Mindedness', 'Intellectual Curiosity', 'Aesthetic Sensitivity', 'Creative Imagination']].iloc[:, 0].mode()[0]
    C = traits.loc[['Conscientiousness', 'Organization', 'Productiveness', 'Responsibility']].iloc[:, 0].mode()[0]
    E = traits.loc[['Extraversion', 'Assertiveness', 'Energy Level', 'Sociability']].iloc[:, 0].mode()[0]
    A = traits.loc[['Agreeableness', 'Compassion', 'Respectfulness', 'Trust']].iloc[:, 0].mode()[0]
    N = traits.loc[['Anxiety', 'Negative Emotionality', 'Depression', 'Emotional Volatility']].iloc[:, 0].mode()[0]

    # Generate and display the personality profile
    profile, summary = generate_profile(O, C, E, A, N)

    # Define subdomains for each main trait
    subdomains = {
        "Openness": ["Aesthetic Sensitivity", "Intellectual Curiosity", "Creative Imagination"],
        "Conscientiousness": ["Organization", "Productiveness", "Responsibility"],
        "Extraversion": ["Sociability", "Assertiveness", "Energy Level"],
        "Agreeableness": ["Compassion", "Respectfulness", "Trust"],
        "Neuroticism": ["Anxiety", "Depression", "Emotional Volatility"]
    }

    # Collect the main traits and their subdomains with values
    main_traits = {
        "Openness": O,
        "Conscientiousness": C,
        "Extraversion": E,
        "Agreeableness": A,
        "Neuroticism": N
    }

    # Generate HTML for the main traits and their subdomains
    main_traits_html = (
        "<h2>Main Traits and Subdomains</h2>"
        "<table border='1' style='border-collapse: collapse; width: 100%;'>"
        "<tr><th>Main Trait</th><th>Level</th><th>Subdomains</th><th>Subdomain Levels</th></tr>"
    )
    for trait, level in main_traits.items():
        subdomain_names = subdomains[trait]
        subdomain_levels = [traits.loc[subdomain, 'Value'] for subdomain in subdomain_names]
        main_traits_html += (
            f"<tr>"
            f"<td><strong>{trait}</strong></td>"
            f"<td>{level}</td>"
            f"<td>{', '.join(subdomain_names)}</td>"
            f"<td>{', '.join(subdomain_levels)}</td>"
            f"</tr>"
        )
    main_traits_html += "</table>"

    # Display the table and profile using HTML
    display(HTML(table_html))
    display(HTML(main_traits_html))
    display(HTML(profile))
    display(HTML(summary))

# Example usage
name_to_search = 'Masum'
extract_traits(name_to_search)
# Out:
# <h2>Traits for Masum</h2><h3>Very High (0)</h3><ul></ul><h3>High (12)</h3><ul><li>Agreeableness</li><li>Conscientiousness</li><li>Open-Mindedness</li><li>Compassion</li><li>Respectfulness</li><li>Trust</li><li>Organization</li><li>Productiveness</li><li>Responsibility</li><li>Intellectual Curiosity</li><li>Aesthetic Sensitivity</li><li>Creative Imagination</li></ul><h3>Medium (4)</h3><ul><li>Extraversion</li><li>Assertiveness</li><li>Energy Level</li><li>Anxiety</li></ul><h3>Low (4)</h3><ul><li>Negative Emotionality</li><li>Sociability</li><li>Depression</li><li>Emotional Volatility</li></ul><h3>Very Low (0)</h3><ul></ul>
# <h2>Main Traits and Subdomains</h2><table border='1' style='border-collapse: collapse; width: 100%;'><tr><th>Main Trait</th><th>Level</th><th>Subdomains</th><th>Subdomain Levels</th></tr><tr><td><strong>Openness</strong></td><td>High</td><td>Aesthetic Sensitivity, Intellectual Curiosity, Creative Imagination</td><td>High, High, High</td></tr><tr><td><strong>Conscientiousness</strong></td><td>High</td><td>Organization, Productiveness, Responsibility</td><td>High, High, High</td></tr><tr><td><strong>Extraversion</strong></td><td>Medium</td><td>Sociability, Assertiveness, Energy Level</td><td>Low, Medium, Medium</td></tr><tr><td><strong>Agreeableness</strong></td><td>High</td><td>Compassion, Respectfulness, Trust</td><td>High, High, High</td></tr><tr><td><strong>Neuroticism</strong></td><td>Low</td><td>Anxiety, Depression, Emotional Volatility</td><td>Medium, Low, Low</td></tr></table>
# <h2>Personality Profile</h2><p><strong>Openness:</strong> Creative and open to new experiences</p><p><strong>Conscientiousness:</strong> Organized and reliable</p><p><strong>Extraversion:</strong> Balanced between sociability and reserved behavior</p><p><strong>Agreeableness:</strong> Cooperative and compassionate</p><p><strong>Neuroticism:</strong> Generally calm and less prone to stress</p>
# <h3>Summary</h3><p>This individual is likely to be creative and open to new experiences also organized and reliable. They may be balanced between sociability and reserved behavior and cooperative and compassionate. They handle stress generally calm and less prone to stress.</p>

# %%
import pandas as pd
from IPython.display import display, HTML

# Load the CSV file
file_path = '/content/drive/MyDrive/Copy of BFI-2.csv'  # Replace with the actual file path
data = pd.read_csv(file_path)

# Define the fixed set of 20 columns
fixed_columns = [
    'Agreeableness', 'Conscientiousness', 'Open-Mindedness', 'Compassion',
    'Respectfulness', 'Trust', 'Organization', 'Productiveness',
    'Responsibility', 'Intellectual Curiosity', 'Aesthetic Sensitivity',
    'Creative Imagination', 'Extraversion', 'Assertiveness', 'Energy Level',
    'Anxiety', 'Negative Emotionality', 'Sociability', 'Depression',
    'Emotional Volatility'
]

# Define the descriptions for each level of each trait
descriptions = {
    "Openness": {
        "Very Low": "Prefers routine, traditional.",
        "Low": "Somewhat conventional, slightly resistant to change.",
        "Medium": "Balanced between openness and conventionality.",
        "High": "Creative and open to new experiences.",
        "Very High": "Very creative, imaginative, open to new experiences."
    },
    "Conscientiousness": {
        "Very Low": "Disorganized, spontaneous.",
        "Low": "Somewhat unreliable, prefers flexibility.",
        "Medium": "Moderately organized and dependable.",
        "High": "Organized and reliable.",
        "Very High": "Highly organized, disciplined."
    },
    "Extraversion": {
        "Very Low": "Very reserved, prefers solitude.",
        "Low": "Somewhat reserved, enjoys some solitary activities.",
        "Medium": "Balanced between sociability and reserved behavior.",
        "High": "Outgoing and sociable.",
        "Very High": "Highly outgoing, energetic, and sociable."
    },
    "Agreeableness": {
        "Very Low": "Competitive, less cooperative.",
        "Low": "Somewhat self-centered, less empathetic.",
        "Medium": "Average in cooperation and compassion.",
        "High": "Cooperative and compassionate.",
        "Very High": "Highly cooperative, kind, and compassionate."
    },
    "Neuroticism": {
        "Very Low": "Very emotionally stable and calm.",
        "Low": "Generally calm, less prone to stress.",
        "Medium": "Average in emotional stability.",
        "High": "Somewhat prone to stress, more sensitive.",
        "Very High": "Prone to stress, emotional instability."
    }
}

# Function to generate the personality profile
def generate_profile(O, C, E, A, N):
    O_desc = descriptions["Openness"][O]
    C_desc = descriptions["Conscientiousness"][C]
    E_desc = descriptions["Extraversion"][E]
    A_desc = descriptions["Agreeableness"][A]
    N_desc = descriptions["Neuroticism"][N]
    profile = (
        f"<h2>Personality Profile</h2>"
        f"<p><strong>Openness:</strong> {O_desc}</p>"
        f"<p><strong>Conscientiousness:</strong> {C_desc}</p>"
        f"<p><strong>Extraversion:</strong> {E_desc}</p>"
        f"<p><strong>Agreeableness:</strong> {A_desc}</p>"
        f"<p><strong>Neuroticism:</strong> {N_desc}</p>"
        f"<h3>Summary</h3>"
        f"<p>This individual is likely to be {O_desc.split(',')[0].lower()} and {C_desc.split(',')[0].lower()}. "
        f"They may be {E_desc.split(',')[0].lower()} and {A_desc.split(',')[0].lower()}. They handle stress {N_desc.split(',')[0].lower()}.</p>"
    )
    return profile

# Function to extract traits for a specific name and categorize them
def extract_traits(name):
    # Filter the dataframe for the given name
    person_data = data[data['Name:'] == name]

    if person_data.empty:
        return f"No data found for {name}."

    # Ensure only the fixed set of columns are considered
    person_data = person_data[fixed_columns]

    # Transpose the dataframe to switch rows and columns for easier processing
    traits = person_data.T
    traits.columns = ['Value']

    # Categorize traits based on their values
    categories = {
        'Very High': [],
        'High': [],
        'Medium': [],
        'Low': [],
        'Very Low': []
    }

    for trait, value in traits['Value'].items():
        if value == 'Very High':
            categories['Very High'].append(trait)
        elif value == 'High':
            categories['High'].append(trait)
        elif value == 'Medium':
            categories['Medium'].append(trait)
        elif value == 'Low':
            categories['Low'].append(trait)
        elif value == 'Very Low':
            categories['Very Low'].append(trait)

    # Create an HTML table for categorized traits
    table_html = "<h2>Traits for {}</h2>".format(name)
    for category, traits_list in categories.items():
        table_html += "<h3>{} ({})</h3><ul>".format(category, len(traits_list))
        for trait in traits_list:
            table_html += "<li>{}</li>".format(trait)
        table_html += "</ul>"

    # Map traits to the OCEAN model
    O = traits.loc[['Open-Mindedness', 'Intellectual Curiosity', 'Aesthetic Sensitivity', 'Creative Imagination']].iloc[:, 0].mode()[0]
    C = traits.loc[['Conscientiousness', 'Organization', 'Productiveness', 'Responsibility']].iloc[:, 0].mode()[0]
    E = traits.loc[['Extraversion', 'Assertiveness', 'Energy Level', 'Sociability']].iloc[:, 0].mode()[0]
    A = traits.loc[['Agreeableness', 'Compassion', 'Respectfulness', 'Trust']].iloc[:, 0].mode()[0]
    N = traits.loc[['Anxiety', 'Negative Emotionality', 'Depression', 'Emotional Volatility']].iloc[:, 0].mode()[0]

    # Generate and display the personality profile
    profile = generate_profile(O, C, E, A, N)

    # Define subdomains for each main trait
    subdomains = {
        "Openness": ["Aesthetic Sensitivity", "Intellectual Curiosity", "Creative Imagination"],
        "Conscientiousness": ["Organization", "Productiveness", "Responsibility"],
        "Extraversion": ["Sociability", "Assertiveness", "Energy Level"],
        "Agreeableness": ["Compassion", "Respectfulness", "Trust"],
        "Neuroticism": ["Anxiety", "Depression", "Emotional Volatility"]
    }

    # Collect the main traits and their subdomains with values
    main_traits = {
        "Openness": O,
        "Conscientiousness": C,
        "Extraversion": E,
        "Agreeableness": A,
        "Neuroticism": N
    }

    # Generate HTML for the main traits and their subdomains
    main_traits_html = "<h2>Main Traits and Subdomains</h2><table border='1'><tr><th>Main Trait</th><th>Level</th><th>Subdomains</th><th>Subdomain Levels</th></tr>"
    for trait, level in main_traits.items():
        subdomain_names = subdomains[trait]
        subdomain_levels = [traits.loc[subdomain, 'Value'] for subdomain in subdomain_names]
        main_traits_html += f"<tr><td><strong>{trait}</strong></td><td>{level}</td><td>{', '.join(subdomain_names)}</td><td>{', '.join(subdomain_levels)}</td></tr>"
    main_traits_html += "</table>"

    # Display the table and profile using HTML
    display(HTML(table_html))
    display(HTML(main_traits_html))
    display(HTML(profile))

# Example usage
name_to_search = 'Masum'
extract_traits(name_to_search)
# Out:
# <h2>Traits for Masum</h2><h3>Very High (0)</h3><ul></ul><h3>High (12)</h3><ul><li>Agreeableness</li><li>Conscientiousness</li><li>Open-Mindedness</li><li>Compassion</li><li>Respectfulness</li><li>Trust</li><li>Organization</li><li>Productiveness</li><li>Responsibility</li><li>Intellectual Curiosity</li><li>Aesthetic Sensitivity</li><li>Creative Imagination</li></ul><h3>Medium (4)</h3><ul><li>Extraversion</li><li>Assertiveness</li><li>Energy Level</li><li>Anxiety</li></ul><h3>Low (4)</h3><ul><li>Negative Emotionality</li><li>Sociability</li><li>Depression</li><li>Emotional Volatility</li></ul><h3>Very Low (0)</h3><ul></ul>
# <h2>Main Traits and Subdomains</h2><table border='1'><tr><th>Main Trait</th><th>Level</th><th>Subdomains</th><th>Subdomain Levels</th></tr><tr><td><strong>Openness</strong></td><td>High</td><td>Aesthetic Sensitivity, Intellectual Curiosity, Creative Imagination</td><td>High, High, High</td></tr><tr><td><strong>Conscientiousness</strong></td><td>High</td><td>Organization, Productiveness, Responsibility</td><td>High, High, High</td></tr><tr><td><strong>Extraversion</strong></td><td>Medium</td><td>Sociability, Assertiveness, Energy Level</td><td>Low, Medium, Medium</td></tr><tr><td><strong>Agreeableness</strong></td><td>High</td><td>Compassion, Respectfulness, Trust</td><td>High, High, High</td></tr><tr><td><strong>Neuroticism</strong></td><td>Low</td><td>Anxiety, Depression, Emotional Volatility</td><td>Medium, Low, Low</td></tr></table>
# <h2>Personality Profile</h2><p><strong>Openness:</strong> Creative and open to new experiences.</p><p><strong>Conscientiousness:</strong> Organized and reliable.</p><p><strong>Extraversion:</strong> Balanced between sociability and reserved behavior.</p><p><strong>Agreeableness:</strong> Cooperative and compassionate.</p><p><strong>Neuroticism:</strong> Generally calm, less prone to stress.</p><h3>Summary</h3><p>This individual is likely to be creative and open to new experiences. and organized and reliable.. They may be balanced between sociability and reserved behavior. and cooperative and compassionate.. They handle stress generally calm.</p>

# %%
import pandas as pd
from IPython.display import display, HTML

# Load the CSV file
file_path = '/content/drive/MyDrive/Copy of BFI-2.csv'  # Replace with the actual file path
data = pd.read_csv(file_path)

# Define the fixed set of 20 columns
fixed_columns = [
    'Agreeableness', 'Conscientiousness', 'Open-Mindedness', 'Compassion',
    'Respectfulness', 'Trust', 'Organization', 'Productiveness',
    'Responsibility', 'Intellectual Curiosity', 'Aesthetic Sensitivity',
    'Creative Imagination', 'Extraversion', 'Assertiveness', 'Energy Level',
    'Anxiety', 'Negative Emotionality', 'Sociability', 'Depression',
    'Emotional Volatility'
]

# Define the descriptions for each level of each trait
descriptions = {
    "Openness": {
        "Very Low": "prefers routine and traditional",
        "Low": "somewhat conventional and slightly resistant to change",
        "Medium": "balanced between openness and conventionality",
        "High": "creative and open to new experiences",
        "Very High": "very creative and also imaginative and open to new experiences"
    },
    "Conscientiousness": {
        "Very Low": "disorganized and spontaneous",
        "Low": "somewhat unreliable and prefers flexibility",
        "Medium": "moderately organized and dependable",
        "High": "organized and reliable",
        "Very High": "highly organized and disciplined"
    },
    "Extraversion": {
        "Very Low": "very reserved and prefers solitude",
        "Low": "somewhat reserved and enjoys some solitary activities",
        "Medium": "balanced between sociability and reserved behavior",
        "High": "outgoing and sociable",
        "Very High": "highly outgoing also energetic and sociable"
    },
    "Agreeableness": {
        "Very Low": "competitive and less cooperative",
        "Low": "somewhat self-centered and less empathetic",
        "Medium": "average in cooperation and compassion",
        "High": "cooperative and compassionate",
        "Very High": "highly cooperative also kind and compassionate"
    },
    "Neuroticism": {
        "Very Low": "very emotionally stable and calm",
        "Low": "generally calm and less prone to stress",
        "Medium": "average in emotional stability",
        "High": "somewhat prone to stress, more sensitive",
        "Very High": "prone to stress and emotional instability"
    }
}

# Function to generate the personality profile
def generate_profile(O, C, E, A, N):
    O_desc = descriptions["Openness"][O]
    C_desc = descriptions["Conscientiousness"][C]
    E_desc = descriptions["Extraversion"][E]
    A_desc = descriptions["Agreeableness"][A]
    N_desc = descriptions["Neuroticism"][N]

    profile = (
        f"<h2>Personality Profile</h2>"
        f"<p><strong>Openness:</strong> {O_desc.capitalize()}</p>"
        f"<p><strong>Conscientiousness:</strong> {C_desc.capitalize()}</p>"
        f"<p><strong>Extraversion:</strong> {E_desc.capitalize()}</p>"
        f"<p><strong>Agreeableness:</strong> {A_desc.capitalize()}</p>"
        f"<p><strong>Neuroticism:</strong> {N_desc.capitalize()}</p>"
    )

    summary = (
        f"<h3>Summary</h3>"
        f"<p>This individual is likely to be {O_desc.split(',')[0]} also {C_desc.split(',')[0]}. "
        f"They may be {E_desc.split(',')[0]} and {A_desc.split(',')[0]}. They handle stress {N_desc.split(',')[0]}.</p>"
    )

    return profile, summary

# Function to extract traits for a specific name and categorize them
def extract_traits(name):
    # Filter the dataframe for the given name
    person_data = data[data['Name:'] == name]

    if person_data.empty:
        return f"No data found for {name}."

    # Ensure only the fixed set of columns are considered
    person_data = person_data[fixed_columns]

    # Transpose the dataframe to switch rows and columns for easier processing
    traits = person_data.T
    traits.columns = ['Value']

    # Categorize traits based on their values
    categories = {
        'Very High': [],
        'High': [],
        'Medium': [],
        'Low': [],
        'Very Low': []
    }

    for trait, value in traits['Value'].items():
        if value == 'Very High':
            categories['Very High'].append(trait)
        elif value == 'High':
            categories['High'].append(trait)
        elif value == 'Medium':
            categories['Medium'].append(trait)
        elif value == 'Low':
            categories['Low'].append(trait)
        elif value == 'Very Low':
            categories['Very Low'].append(trait)

    # Create an HTML table for categorized traits
    table_html = "<h2>Traits for {}</h2>".format(name)
    for category, traits_list in categories.items():
        table_html += "<h3>{} ({})</h3><ul>".format(category, len(traits_list))
        for trait in traits_list:
            table_html += "<li>{}</li>".format(trait)
        table_html += "</ul>"

    # Map traits to the OCEAN model
    O = traits.loc[['Open-Mindedness', 'Intellectual Curiosity', 'Aesthetic Sensitivity', 'Creative Imagination']].iloc[:, 0].mode()[0]
    C = traits.loc[['Conscientiousness', 'Organization', 'Productiveness', 'Responsibility']].iloc[:, 0].mode()[0]
    E = traits.loc[['Extraversion', 'Assertiveness', 'Energy Level', 'Sociability']].iloc[:, 0].mode()[0]
    A = traits.loc[['Agreeableness', 'Compassion', 'Respectfulness', 'Trust']].iloc[:, 0].mode()[0]
    N = traits.loc[['Anxiety', 'Negative Emotionality', 'Depression', 'Emotional Volatility']].iloc[:, 0].mode()[0]

    # Generate and display the personality profile
    profile, summary = generate_profile(O, C, E, A, N)

    # Define subdomains for each main trait
    subdomains = {
        "Openness": ["Aesthetic Sensitivity", "Intellectual Curiosity", "Creative Imagination"],
        "Conscientiousness": ["Organization", "Productiveness", "Responsibility"],
        "Extraversion": ["Sociability", "Assertiveness", "Energy Level"],
        "Agreeableness": ["Compassion", "Respectfulness", "Trust"],
        "Neuroticism": ["Anxiety", "Depression", "Emotional Volatility"]
    }

    # Collect the main traits and their subdomains with values
    main_traits = {
        "Openness": O,
        "Conscientiousness": C,
        "Extraversion": E,
        "Agreeableness": A,
        "Neuroticism": N
    }

    # Generate HTML for the main traits and their subdomains
    main_traits_html = (
        "<h2>Main Traits and Subdomains</h2>"
        "<table border='1' style='border-collapse: collapse; width: 100%;'>"
        "<tr><th>Main Trait</th><th>Level</th><th>Subdomains</th><th>Subdomain Levels</th></tr>"
    )
    for trait, level in main_traits.items():
        subdomain_names = subdomains[trait]
        subdomain_levels = [traits.loc[subdomain, 'Value'] for subdomain in subdomain_names]
        main_traits_html += (
            f"<tr>"
            f"<td><strong>{trait}</strong></td>"
            f"<td>{level}</td>"
            f"<td>{', '.join(subdomain_names)}</td>"
            f"<td>{', '.join(subdomain_levels)}</td>"
            f"</tr>"
        )
    main_traits_html += "</table>"

    # Display the table and profile using HTML
    display(HTML(table_html))
    display(HTML(main_traits_html))
    display(HTML(profile))
    display(HTML(summary))

# Example usage
name_to_search = 'Masum'
extract_traits(name_to_search)
# Out:
# <h2>Traits for Masum</h2><h3>Very High (0)</h3><ul></ul><h3>High (12)</h3><ul><li>Agreeableness</li><li>Conscientiousness</li><li>Open-Mindedness</li><li>Compassion</li><li>Respectfulness</li><li>Trust</li><li>Organization</li><li>Productiveness</li><li>Responsibility</li><li>Intellectual Curiosity</li><li>Aesthetic Sensitivity</li><li>Creative Imagination</li></ul><h3>Medium (4)</h3><ul><li>Extraversion</li><li>Assertiveness</li><li>Energy Level</li><li>Anxiety</li></ul><h3>Low (4)</h3><ul><li>Negative Emotionality</li><li>Sociability</li><li>Depression</li><li>Emotional Volatility</li></ul><h3>Very Low (0)</h3><ul></ul>
# <h2>Main Traits and Subdomains</h2><table border='1' style='border-collapse: collapse; width: 100%;'><tr><th>Main Trait</th><th>Level</th><th>Subdomains</th><th>Subdomain Levels</th></tr><tr><td><strong>Openness</strong></td><td>High</td><td>Aesthetic Sensitivity, Intellectual Curiosity, Creative Imagination</td><td>High, High, High</td></tr><tr><td><strong>Conscientiousness</strong></td><td>High</td><td>Organization, Productiveness, Responsibility</td><td>High, High, High</td></tr><tr><td><strong>Extraversion</strong></td><td>Medium</td><td>Sociability, Assertiveness, Energy Level</td><td>Low, Medium, Medium</td></tr><tr><td><strong>Agreeableness</strong></td><td>High</td><td>Compassion, Respectfulness, Trust</td><td>High, High, High</td></tr><tr><td><strong>Neuroticism</strong></td><td>Low</td><td>Anxiety, Depression, Emotional Volatility</td><td>Medium, Low, Low</td></tr></table>
# <h2>Personality Profile</h2><p><strong>Openness:</strong> Creative and open to new experiences</p><p><strong>Conscientiousness:</strong> Organized and reliable</p><p><strong>Extraversion:</strong> Balanced between sociability and reserved behavior</p><p><strong>Agreeableness:</strong> Cooperative and compassionate</p><p><strong>Neuroticism:</strong> Generally calm and less prone to stress</p>
# <h3>Summary</h3><p>This individual is likely to be creative and open to new experiences also organized and reliable. They may be balanced between sociability and reserved behavior and cooperative and compassionate. They handle stress generally calm and less prone to stress.</p>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML

# Load the CSV file
file_path = '/content/drive/MyDrive/Copy of BFI-2.csv'  # Replace with the actual file path
data = pd.read_csv(file_path)

# Define the fixed set of 20 columns
fixed_columns = [
    'Agreeableness', 'Conscientiousness', 'Open-Mindedness', 'Compassion',
    'Respectfulness', 'Trust', 'Organization', 'Productiveness',
    'Responsibility', 'Intellectual Curiosity', 'Aesthetic Sensitivity',
    'Creative Imagination', 'Extraversion', 'Assertiveness', 'Energy Level',
    'Anxiety', 'Negative Emotionality', 'Sociability', 'Depression',
    'Emotional Volatility'
]

# Define the descriptions for each level of each trait
descriptions = {
    "Open-Mindedness": {
        "Very Low": "prefers routine and traditional",
        "Low": "somewhat conventional and slightly resistant to change",
        "Medium": "balanced between openness and conventionality",
        "High": "creative and open to new experiences",
        "Very High": "very creative and also imaginative and open to new experiences"
    },
    "Conscientiousness": {
        "Very Low": "disorganized and spontaneous",
        "Low": "somewhat unreliable and prefers flexibility",
        "Medium": "moderately organized and dependable",
        "High": "organized and reliable",
        "Very High": "highly organized and disciplined"
    },
    "Extraversion": {
        "Very Low": "very reserved and prefers solitude",
        "Low": "somewhat reserved and enjoys some solitary activities",
        "Medium": "balanced between sociability and reserved behavior",
        "High": "outgoing and sociable",
        "Very High": "highly outgoing also energetic and sociable"
    },
    "Agreeableness": {
        "Very Low": "competitive and less cooperative",
        "Low": "somewhat self-centered and less empathetic",
        "Medium": "average in cooperation and compassion",
        "High": "cooperative and compassionate",
        "Very High": "highly cooperative also kind and compassionate"
    },
    "Negative Emotionality": {
        "Very Low": "very emotionally stable and calm",
        "Low": "generally calm and less prone to stress",
        "Medium": "average in emotional stability",
        "High": "somewhat prone to stress, more sensitive",
        "Very High": "prone to stress and emotional instability"
    }
}

# Function to generate the personality profile
def generate_profile(O, C, E, A, N):
    O_desc = descriptions["Open-Mindedness"][O]
    C_desc = descriptions["Conscientiousness"][C]
    E_desc = descriptions["Extraversion"][E]
    A_desc = descriptions["Agreeableness"][A]
    N_desc = descriptions["Negative Emotionality"][N]

    profile = (
        f"<h2>Personality Profile</h2>"
        f"<p><strong>Openness:</strong> {O_desc.capitalize()}</p>"
        f"<p><strong>Conscientiousness:</strong> {C_desc.capitalize()}</p>"
        f"<p><strong>Extraversion:</strong> {E_desc.capitalize()}</p>"
        f"<p><strong>Agreeableness:</strong> {A_desc.capitalize()}</p>"
        f"<p><strong>Neuroticism:</strong> {N_desc.capitalize()}</p>"
    )

    summary = (
        f"<h3>Summary</h3>"
        f"<p>This individual is likely to be {O_desc.split(' and ')[0]} and {C_desc.split(' and ')[0]}. "
        f"They may be {E_desc.split(' and ')[0]} and {A_desc.split(' and ')[0]}. They handle stress {N_desc.split(' and ')[0]}.</p>"
    )

    return profile, summary

# Function to extract traits for a specific name and categorize them
def extract_traits(name):
    # Filter the dataframe for the given name
    person_data = data[data['Name:'] == name]

    if person_data.empty:
        return f"No data found for {name}."

    # Ensure only the fixed set of columns are considered
    person_data = person_data[fixed_columns]

    # Transpose the dataframe to switch rows and columns for easier processing
    traits = person_data.T
    traits.columns = ['Value']

    # Categorize traits based on their values
    categories = {
        'Very High': [],
        'High': [],
        'Medium': [],
        'Low': [],
        'Very Low': []
    }

    for trait, value in traits['Value'].items():
        categories[value].append(trait)

    # Create an HTML table for categorized traits
    table_html = f"<h2>Traits for {name}</h2>"
    for category, traits_list in categories.items():
        table_html += f"<h3>{category} ({len(traits_list)})</h3><ul>"
        for trait in traits_list:
            table_html += f"<li>{trait}</li>"
        table_html += "</ul>"

    # Map traits to the OCEAN model
    O = traits.loc[['Open-Mindedness', 'Intellectual Curiosity', 'Aesthetic Sensitivity', 'Creative Imagination']].iloc[:, 0].mode()[0]
    C = traits.loc[['Conscientiousness', 'Organization', 'Productiveness', 'Responsibility']].iloc[:, 0].mode()[0]
    E = traits.loc[['Extraversion', 'Assertiveness', 'Energy Level', 'Sociability']].iloc[:, 0].mode()[0]
    A = traits.loc[['Agreeableness', 'Compassion', 'Respectfulness', 'Trust']].iloc[:, 0].mode()[0]
    N = traits.loc[['Anxiety', 'Negative Emotionality', 'Depression', 'Emotional Volatility']].iloc[:, 0].mode()[0]

    # Generate and display the personality profile
    profile, summary = generate_profile(O, C, E, A, N)

    # Define subdomains for each main trait
    subdomains = {
        "Open-Mindedness": ["Aesthetic Sensitivity", "Intellectual Curiosity", "Creative Imagination"],
        "Conscientiousness": ["Organization", "Productiveness", "Responsibility"],
        "Extraversion": ["Sociability", "Assertiveness", "Energy Level"],
        "Agreeableness": ["Compassion", "Respectfulness", "Trust"],
        "Negative Emotionality": ["Anxiety", "Depression", "Emotional Volatility"]
    }

    # Collect the main traits and their subdomains with values
    main_traits = {
        "Open-Mindedness": O,
        "Conscientiousness": C,
        "Extraversion": E,
        "Agreeableness": A,
        "Negative Emotionality": N
    }

    # Generate HTML for the main traits and their subdomains
    main_traits_html = (
        "<h2>Main Traits and Subdomains</h2>"
        "<table border='1' style='border-collapse: collapse; width: 100%;'>"
        "<tr><th>Main Trait</th><th>Level</th><th>Subdomains</th><th>Subdomain Levels</th></tr>"
    )
    for trait, level in main_traits.items():
        subdomain_names = subdomains[trait]
        subdomain_levels = [traits.loc[subdomain, 'Value'] for subdomain in subdomain_names]
        main_traits_html += (
            f"<tr>"
            f"<td><strong>{trait}</strong></td>"
            f"<td>{level}</td>"
            f"<td>{', '.join(subdomain_names)}</td>"
            f"<td>{', '.join(subdomain_levels)}</td>"
            f"</tr>"
        )
    main_traits_html += "</table>"

    # Plot the bar chart for main traits
    main_traits_levels = {trait: traits.loc[subdomains[trait], 'Value'].value_counts().to_dict() for trait in main_traits.keys()}
    main_traits_levels_df = pd.DataFrame(main_traits_levels).fillna(0)

    plt.figure(figsize=(12, 8))
    main_traits_levels_df.T.plot(kind='bar', stacked=True)
    plt.title('Distribution of Trait Levels')
    plt.xlabel('Main Traits')
    plt.ylabel('Number of Subdomains')
    plt.xticks(rotation=45)
    plt.legend(title='Levels')
    plt.tight_layout()
    plt.show()

    # Display the table and profile using HTML
    display(HTML(table_html))
    display(HTML(main_traits_html))
    display(HTML(profile))
    display(HTML(summary))

# Example usage
name_to_search = 'Masum'
extract_traits(name_to_search)
# Out:
# <h2>Traits for Masum</h2><h3>Very High (0)</h3><ul></ul><h3>High (12)</h3><ul><li>Agreeableness</li><li>Conscientiousness</li><li>Open-Mindedness</li><li>Compassion</li><li>Respectfulness</li><li>Trust</li><li>Organization</li><li>Productiveness</li><li>Responsibility</li><li>Intellectual Curiosity</li><li>Aesthetic Sensitivity</li><li>Creative Imagination</li></ul><h3>Medium (4)</h3><ul><li>Extraversion</li><li>Assertiveness</li><li>Energy Level</li><li>Anxiety</li></ul><h3>Low (4)</h3><ul><li>Negative Emotionality</li><li>Sociability</li><li>Depression</li><li>Emotional Volatility</li></ul><h3>Very Low (0)</h3><ul></ul>
# <h2>Main Traits and Subdomains</h2><table border='1' style='border-collapse: collapse; width: 100%;'><tr><th>Main Trait</th><th>Level</th><th>Subdomains</th><th>Subdomain Levels</th></tr><tr><td><strong>Open-Mindedness</strong></td><td>High</td><td>Aesthetic Sensitivity, Intellectual Curiosity, Creative Imagination</td><td>High, High, High</td></tr><tr><td><strong>Conscientiousness</strong></td><td>High</td><td>Organization, Productiveness, Responsibility</td><td>High, High, High</td></tr><tr><td><strong>Extraversion</strong></td><td>Medium</td><td>Sociability, Assertiveness, Energy Level</td><td>Low, Medium, Medium</td></tr><tr><td><strong>Agreeableness</strong></td><td>High</td><td>Compassion, Respectfulness, Trust</td><td>High, High, High</td></tr><tr><td><strong>Negative Emotionality</strong></td><td>Low</td><td>Anxiety, Depression, Emotional Volatility</td><td>Medium, Low, Low</td></tr></table>
# <h2>Personality Profile</h2><p><strong>Openness:</strong> Creative and open to new experiences</p><p><strong>Conscientiousness:</strong> Organized and reliable</p><p><strong>Extraversion:</strong> Balanced between sociability and reserved behavior</p><p><strong>Agreeableness:</strong> Cooperative and compassionate</p><p><strong>Neuroticism:</strong> Generally calm and less prone to stress</p>
# <h3>Summary</h3><p>This individual is likely to be creative and organized. They may be balanced between sociability and cooperative. They handle stress generally calm.</p>

# %%
from IPython.display import display, HTML
import pandas as pd

# Load the CSV file
file_path = '/content/drive/MyDrive/Copy of BFI-2.csv'  # Replace with the actual file path
data = pd.read_csv(file_path)

# Define the fixed set of 20 columns
fixed_columns = [
    'Agreeableness', 'Conscientiousness', 'Open-Mindedness', 'Compassion',
    'Respectfulness', 'Trust', 'Organization', 'Productiveness',
    'Responsibility', 'Intellectual Curiosity', 'Aesthetic Sensitivity',
    'Creative Imagination', 'Extraversion', 'Assertiveness', 'Energy Level',
    'Anxiety', 'Negative Emotionality', 'Sociability', 'Depression',
    'Emotional Volatility'
]

# Define the descriptions for each level of each trait
descriptions = {
    "Openness": {
        "Very Low": "prefers routine and traditional",
        "Low": "somewhat conventional and slightly resistant to change",
        "Medium": "balanced between openness and conventionality",
        "High": "creative and open to new experiences",
        "Very High": "very creative and also imaginative and open to new experiences"
    },
    "Conscientiousness": {
        "Very Low": "disorganized and spontaneous",
        "Low": "somewhat unreliable and prefers flexibility",
        "Medium": "moderately organized and dependable",
        "High": "organized and reliable",
        "Very High": "highly organized and disciplined"
    },
    "Extraversion": {
        "Very Low": "very reserved and prefers solitude",
        "Low": "somewhat reserved and enjoys some solitary activities",
        "Medium": "balanced between sociability and reserved behavior",
        "High": "outgoing and sociable",
        "Very High": "highly outgoing also energetic and sociable"
    },
    "Agreeableness": {
        "Very Low": "competitive and less cooperative",
        "Low": "somewhat self-centered and less empathetic",
        "Medium": "average in cooperation and compassion",
        "High": "cooperative and compassionate",
        "Very High": "highly cooperative also kind and compassionate"
    },
    "Neuroticism": {
        "Very Low": "very emotionally stable and calm",
        "Low": "generally calm and less prone to stress",
        "Medium": "average in emotional stability",
        "High": "somewhat prone to stress, more sensitive",
        "Very High": "prone to stress and emotional instability"
    }
}

# Function to generate the personality profile
def generate_profile(O, C, E, A, N):
    O_desc = descriptions["Openness"][O]
    C_desc = descriptions["Conscientiousness"][C]
    E_desc = descriptions["Extraversion"][E]
    A_desc = descriptions["Agreeableness"][A]
    N_desc = descriptions["Neuroticism"][N]

    profile = (
        f"<h2>Personality Profile</h2>"
        f"<p><strong>Openness:</strong> {O_desc.capitalize()}</p>"
        f"<p><strong>Conscientiousness:</strong> {C_desc.capitalize()}</p>"
        f"<p><strong>Extraversion:</strong> {E_desc.capitalize()}</p>"
        f"<p><strong>Agreeableness:</strong> {A_desc.capitalize()}</p>"
        f"<p><strong>Neuroticism:</strong> {N_desc.capitalize()}</p>"
    )

    summary = (
        f"<h3>Summary</h3>"
        f"<p>This individual is likely to be {O_desc.split(',')[0]} also {C_desc.split(',')[0]}. "
        f"They may be {E_desc.split(',')[0]} and {A_desc.split(',')[0]}. They handle stress {N_desc.split(',')[0]}.</p>"
    )

    return profile, summary

# Function to extract traits for a specific name and categorize them
def extract_traits(name):
    # Filter the dataframe for the given name
    person_data = data[data['Name:'] == name]

    if person_data.empty:
        return f"No data found for {name}."

    # Ensure only the fixed set of columns are considered
    person_data = person_data[fixed_columns]

    # Transpose the dataframe to switch rows and columns for easier processing
    traits = person_data.T
    traits.columns = ['Value']

    # Categorize traits based on their values
    categories = {
        'Very High': [],
        'High': [],
        'Medium': [],
        'Low': [],
        'Very Low': []
    }

    for trait, value in traits['Value'].items():
        if value == 'Very High':
            categories['Very High'].append(trait)
        elif value == 'High':
            categories['High'].append(trait)
        elif value == 'Medium':
            categories['Medium'].append(trait)
        elif value == 'Low':
            categories['Low'].append(trait)
        elif value == 'Very Low':
            categories['Very Low'].append(trait)

    # Create an HTML table for categorized traits with color coding
    table_html = "<h2>Traits for {}</h2>".format(name)
    for category, traits_list in categories.items():
        color = ""
        if category == 'Very High':
            color = "green"
        elif category == 'High':
            color = "yellow"
        elif category == 'Medium':
            color = "orange"
        elif category == 'Low':
            color = "red"

        table_html += f"<h3 style='color: {color}'>{category} ({len(traits_list)})</h3><ul>"
        for trait in traits_list:
            table_html += "<li>{}</li>".format(trait)
        table_html += "</ul>"

    # Map traits to the OCEAN model
    O = traits.loc[['Open-Mindedness', 'Intellectual Curiosity', 'Aesthetic Sensitivity', 'Creative Imagination']].iloc[:, 0].mode()[0]
    C = traits.loc[['Conscientiousness', 'Organization', 'Productiveness', 'Responsibility']].iloc[:, 0].mode()[0]
    E = traits.loc[['Extraversion', 'Assertiveness', 'Energy Level', 'Sociability']].iloc[:, 0].mode()[0]
    A = traits.loc[['Agreeableness', 'Compassion', 'Respectfulness', 'Trust']].iloc[:, 0].mode()[0]
    N = traits.loc[['Anxiety', 'Negative Emotionality', 'Depression', 'Emotional Volatility']].iloc[:, 0].mode()[0]

    # Generate and display the personality profile
    profile, summary = generate_profile(O, C, E, A, N)

    # Define subdomains for each main trait
        # Define subdomains for each main trait
    subdomains = {
        "Openness": ["Aesthetic Sensitivity", "Intellectual Curiosity", "Creative Imagination"],
        "Conscientiousness": ["Organization", "Productiveness", "Responsibility"],
        "Extraversion": ["Sociability", "Assertiveness", "Energy Level"],
        "Agreeableness": ["Compassion", "Respectfulness", "Trust"],
        "Neuroticism": ["Anxiety", "Depression", "Emotional Volatility"]
    }

    # Collect the main traits and their subdomains with values
    main_traits = {
        "Openness": O,
        "Conscientiousness": C,
        "Extraversion": E,
        "Agreeableness": A,
        "Neuroticism": N
    }

    # Generate HTML for the main traits and their subdomains
    main_traits_html = (
        "<h2>Main Traits and Subdomains</h2>"
        "<table border='1' style='border-collapse: collapse; width: 100%;'>"
        "<tr><th>Main Trait</th><th>Level</th><th>Subdomains</th><th>Subdomain Levels</th></tr>"
    )
    for trait, level in main_traits.items():
        subdomain_names = subdomains[trait]
        subdomain_levels = [traits.loc[subdomain, 'Value'] for subdomain in subdomain_names]
        main_traits_html += (
            f"<tr>"
            f"<td><strong>{trait}</strong></td>"
            f"<td>{level}</td>"
            f"<td>{', '.join(subdomain_names)}</td>"
            f"<td>{', '.join(subdomain_levels)}</td>"
            f"</tr>"
        )
    main_traits_html += "</table>"

    # Display the table and profile using HTML
    display(HTML(table_html))
    display(HTML(main_traits_html))
    display(HTML(profile))
    display(HTML(summary))

# Example usage
name_to_search = 'Masum'
extract_traits(name_to_search)
# Out:
# <h2>Traits for Masum</h2><h3 style='color: green'>Very High (0)</h3><ul></ul><h3 style='color: yellow'>High (12)</h3><ul><li>Agreeableness</li><li>Conscientiousness</li><li>Open-Mindedness</li><li>Compassion</li><li>Respectfulness</li><li>Trust</li><li>Organization</li><li>Productiveness</li><li>Responsibility</li><li>Intellectual Curiosity</li><li>Aesthetic Sensitivity</li><li>Creative Imagination</li></ul><h3 style='color: orange'>Medium (4)</h3><ul><li>Extraversion</li><li>Assertiveness</li><li>Energy Level</li><li>Anxiety</li></ul><h3 style='color: red'>Low (4)</h3><ul><li>Negative Emotionality</li><li>Sociability</li><li>Depression</li><li>Emotional Volatility</li></ul><h3 style='color: '>Very Low (0)</h3><ul></ul>
# <h2>Main Traits and Subdomains</h2><table border='1' style='border-collapse: collapse; width: 100%;'><tr><th>Main Trait</th><th>Level</th><th>Subdomains</th><th>Subdomain Levels</th></tr><tr><td><strong>Openness</strong></td><td>High</td><td>Aesthetic Sensitivity, Intellectual Curiosity, Creative Imagination</td><td>High, High, High</td></tr><tr><td><strong>Conscientiousness</strong></td><td>High</td><td>Organization, Productiveness, Responsibility</td><td>High, High, High</td></tr><tr><td><strong>Extraversion</strong></td><td>Medium</td><td>Sociability, Assertiveness, Energy Level</td><td>Low, Medium, Medium</td></tr><tr><td><strong>Agreeableness</strong></td><td>High</td><td>Compassion, Respectfulness, Trust</td><td>High, High, High</td></tr><tr><td><strong>Neuroticism</strong></td><td>Low</td><td>Anxiety, Depression, Emotional Volatility</td><td>Medium, Low, Low</td></tr></table>
# <h2>Personality Profile</h2><p><strong>Openness:</strong> Creative and open to new experiences</p><p><strong>Conscientiousness:</strong> Organized and reliable</p><p><strong>Extraversion:</strong> Balanced between sociability and reserved behavior</p><p><strong>Agreeableness:</strong> Cooperative and compassionate</p><p><strong>Neuroticism:</strong> Generally calm and less prone to stress</p>
# <h3>Summary</h3><p>This individual is likely to be creative and open to new experiences also organized and reliable. They may be balanced between sociability and reserved behavior and cooperative and compassionate. They handle stress generally calm and less prone to stress.</p>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to generate radar chart
def generate_radar_chart(traits):
    traits_labels = list(traits.index)
    trait_values = traits['Value']

    angles = np.linspace(0, 2 * np.pi, len(traits_labels), endpoint=False).tolist()

    fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

    trait_values = trait_values.tolist()
    trait_values += trait_values[:1]
    angles += angles[:1]

    ax.fill(angles, trait_values, color='blue', alpha=0.25)
    ax.plot(angles, trait_values, color='blue', linewidth=2)

    ax.set_yticklabels([])
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(traits_labels, fontsize=10, fontweight='bold')

    plt.title('Personality Radar Chart', size=20, color='blue', y=1.1)

    plt.show()

# Function to extract traits for a specific name and categorize them
def extract_traits(name):
    # Filter the dataframe for the given name
    person_data = data[data['Name:'] == name]

    if person_data.empty:
        return f"No data found for {name}."

    # Ensure only the fixed set of columns are considered
    person_data = person_data[fixed_columns]

    # Transpose the dataframe to switch rows and columns for easier processing
    traits = person_data.T
    traits.columns = ['Value']

    # Categorize traits based on their values
    categories = {
        'Very High': [],
        'High': [],
        'Medium': [],
        'Low': [],
        'Very Low': []
    }

    for trait, value in traits['Value'].items():
        if value == 'Very High':
            categories['Very High'].append(trait)
        elif value == 'High':
            categories['High'].append(trait)
        elif value == 'Medium':
            categories['Medium'].append(trait)
        elif value == 'Low':
            categories['Low'].append(trait)
        elif value == 'Very Low':
            categories['Very Low'].append(trait)

    # Create an HTML table for categorized traits with color coding
    table_html = "<h2>Traits for {}</h2>".format(name)
    for category, traits_list in categories.items():
        color = ""
        if category == 'Very High':
            color = "green"
        elif category == 'High':
            color = "yellow"
        elif category == 'Medium':
            color = "orange"
        elif category == 'Low':
            color = "red"

        table_html += f"<h3 style='color: {color}'>{category} ({len(traits_list)})</h3><ul>"
        for trait in traits_list:
            table_html += "<li>{}</li>".format(trait)
        table_html += "</ul>"

    # Generate radar chart for personality profile
    generate_radar_chart(traits)

    # Map traits to the OCEAN model
    O = traits.loc[['Open-Mindedness', 'Intellectual Curiosity', 'Aesthetic Sensitivity', 'Creative Imagination']].iloc[:, 0].mode()[0]
    C = traits.loc[['Conscientiousness', 'Organization', 'Productiveness', 'Responsibility']].iloc[:, 0].mode()[0]
    E = traits.loc[['Extraversion', 'Assertiveness', 'Energy Level', 'Sociability']].iloc[:, 0].mode()[0]
    A = traits.loc[['Agreeableness', 'Compassion', 'Respectfulness', 'Trust']].iloc[:, 0].mode()[0]
    N = traits.loc[['Anxiety', 'Negative Emotionality', 'Depression', 'Emotional Volatility']].iloc[:, 0].mode()[0]

    # Generate and display the personality profile
    profile, summary = generate_profile(O, C, E, A, N)

    # Display the table and profile using HTML
    display(HTML(table_html))
    display(HTML(profile))
    display(HTML(summary))

# Example usage
name_to_search = 'Masum'
extract_traits(name_to_search)
# Out:
# <h2>Traits for Masum</h2><h3 style='color: green'>Very High (0)</h3><ul></ul><h3 style='color: yellow'>High (12)</h3><ul><li>Agreeableness</li><li>Conscientiousness</li><li>Open-Mindedness</li><li>Compassion</li><li>Respectfulness</li><li>Trust</li><li>Organization</li><li>Productiveness</li><li>Responsibility</li><li>Intellectual Curiosity</li><li>Aesthetic Sensitivity</li><li>Creative Imagination</li></ul><h3 style='color: orange'>Medium (4)</h3><ul><li>Extraversion</li><li>Assertiveness</li><li>Energy Level</li><li>Anxiety</li></ul><h3 style='color: red'>Low (4)</h3><ul><li>Negative Emotionality</li><li>Sociability</li><li>Depression</li><li>Emotional Volatility</li></ul><h3 style='color: '>Very Low (0)</h3><ul></ul>
# <h2>Personality Profile</h2><p><strong>Openness:</strong> Creative and open to new experiences</p><p><strong>Conscientiousness:</strong> Organized and reliable</p><p><strong>Extraversion:</strong> Balanced between sociability and reserved behavior</p><p><strong>Agreeableness:</strong> Cooperative and compassionate</p><p><strong>Neuroticism:</strong> Generally calm and less prone to stress</p>
# <h3>Summary</h3><p>This individual is likely to be creative and open to new experiences also organized and reliable. They may be balanced between sociability and reserved behavior and cooperative and compassionate. They handle stress generally calm and less prone to stress.</p>
